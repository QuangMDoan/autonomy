# %%
import numpy as np 
a = np.ones((4, 6)) 
b = 2 * np.ones((4, 1)) 

# what is the output of a+b ? 
# print(f"a+b, shape: {(a+b).shape} \n {a+b}")

# %%
a = np.ones((1, 6)) 
b = 2 * np.ones((4, 1)) 

# what is the output of a+b ? 
# print(f"a+b, shape: {(a+b).shape} \n {a+b}")

# %%
a = np.ones(6)
b = 2 * np.ones((4, 1)) 
# what is the output of a+b ? 
# print(f"a+b, shape: {(a+b).shape} \n {a+b}")
