# %% [markdown]
# # A* Motion Planning

# %%
# The autoreload extension will automatically load in new code as you edit files, 
# so you don't need to restart the kernel every time
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from P1_astar import DetOccupancyGrid2D, AStar

width = 10
height = 10
obstacles = [((6,7),(8,8)),((2,2),(4,3)),((2,5),(4,7)),((6,3),(8,5))]
occupancy = DetOccupancyGrid2D(width, height, obstacles)

x_init = (1, 9)
x_goal = (9, 1)

astar = AStar((0, 0), (width, height), x_init, x_goal, occupancy, AStar.l2_norm_distance)
if astar.solve():
    plt.rcParams['figure.figsize'] = [5, 5]
    astar.plot_path()
    astar.plot_tree()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
astar = AStar((0, 0), (width, height), x_init, x_goal, occupancy, AStar.linf_norm_distance)
if astar.solve():
    plt.rcParams['figure.figsize'] = [5, 5]
    astar.plot_path()
    astar.plot_tree()
